# %%
# Initialize Otter
import otter
grader = otter.Notebook("hw1-task1.ipynb")

# %% [markdown]
# # Homework 1 - Task 1
# ## eDNA and Conventional Fish Surveys
#
# **Based on:** McElroy et al. (2020). *Calibrating environmental DNA metabarcoding to conventional surveys for measuring fish species richness.* Frontiers in Ecology and Evolution.
#
# In this set of exercises you'll wrangle and explore a dataset comparing **eDNA metabarcoding** and **traditional survey methods** for detecting fish species across 68 global freshwater lakes.
#
# The dataset has the following key columns:
#
# | Column | Description |
# |---|---|
# | `author` | First author of the primary study |
# | `area_ha` | Lake area (hectares) |
# | `dna_richness` | Number of fish species detected by eDNA |
# | `trad_richness` | Number of fish species detected by conventional surveys |
# | `dna_only` | Number of species found **only** by eDNA |
# | `trad_only` | Number of species found **only** by conventional surveys |
# | `shared` | Number of species found by **both** methods |
# | `union` | Total unique species (`dna_only + trad_only + shared`) |
# | `marker_cat` | Whether single or multiple genetic markers were used (single vs. multiple eDNA markers) |
# | `gear_cat` | Whether single or multiple conventional survey gear types were used (single vs. multiple) |
# | `total_vol_liter` | Total volume of water sampled (litres) |
#
# There is no statistics or ML methods in this notebook. Its goal is to review some core Python data wrangling. Along the way you'll practice core pandas skills: loading data, inspecting structure, filtering, grouping, sorting, and deriving new columns.
#
# ---

# %% [markdown]
# ## 1.
#
# Import `pandas` with the alias `pd` and `numpy` with the alias `np`.

# %%
# Import necessary libraries.
import pandas as pd
import numpy as np

# %% [markdown]
# ## 2.
#
# Read in the lakes data and store it in a variable called `df`.

# %%
# Read the lakes data and save it as 'df'.
df = pd.read_csv("lakes_data.csv")

# %% [markdown]
# ## 3.
#
# How many rows and columns does `df` have? Store the number of rows in a variable called `rows` and the number of columns in a variable called `cols`.

# %%
# Taking the first index (0) of the shape of df, which tells us the number of rows in the dataframe.
rows= df.shape[0]

# Taking the second index (1) of the shape of df, which tells us the number of columns in the dataframe.
cols = df.shape[1]

print("Number of rows:", rows)
print("Number of columns:", cols)
# Out:
# Number of rows: 68
# Number of columns: 17

# %%
grader.check("q3")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 grader.check("q3")
#
# File /opt/anaconda3/envs/eds232-env/lib/python3.10/site-packages/otter/check/utils.py:241, in logs_event.<locals>.event_logger(wrapped, self, args, kwargs)
#     239 except Exception as e:
#     240     self._log_event(event_type, success=False, error=e)
# --> 241     raise e
#     243 if ret is None:
#     244     ret = LoggedEventReturnValue(None)
#
# File /opt/anaconda3/envs/eds232-env/lib/python3.10/site-packages/otter/check/utils.py:237, in logs_event.<locals>.event_logger(wrapped, self, args, kwargs)
#     232 """
#     233 Runs a method, catching any errors and logging the call. Returns the unwrapped return value
#     234 of the wrapped function.
#     235 """
#     236 try:
# --> 237     ret: Optional[LoggedEventReturnValue[T]] = wrapped(*args, **kwargs)
#     239 except Exception as e:
#     240     self._log_event(event_type, success=False, error=e)
#
# File /opt/anaconda3/envs/eds232-env/lib/python3.10/site-packages/otter/check/notebook.py:286, in Notebook.check(self, question, global_env)
#     284 # run the check
#     285 self._logger.debug(f"Calling checker")
# --> 286 result = Checker.check(test_path, self._nbmeta_config, test_name, global_env)
#     288 return LoggedEventReturnValue(result, question=question, shelve_env=global_env)
#
# File /opt/anaconda3/envs/eds232-env/lib/python3.10/site-packages/otter/execute/checker.py:80, in Checker.check(cls, nb_or_test_path, nbmeta_config, test_name, global_env)
#      58 @classmethod
#      59 def check(
#      60     cls,
#    (...)
#      64     global_env: Optional[dict[str, Any]] = None,
#      65 ) -> TestFile:
#      66     """
#      67     Checks a global environment against a test, which may be stored in a file or in a notebook's
#      68     metadata.
#    (...)
#      78         given global environment
#      79     """
# ---> 80     test = create_test_file(nb_or_test_path, nbmeta_config, test_name=test_name)
#      82     if global_env is None:
#      83         global_env = inspect.currentframe().f_back.f_globals
#
# File /opt/anaconda3/envs/eds232-env/lib/python3.10/site-packages/otter/test_files/__init__.py:63, in create_test_file(path, nbmeta_config, test_name)
#      60         return NotebookMetadataOKTestFile.from_nbmeta_config(path, nbmeta_config, test_name)
#      62     else:
# ---> 63         return NotebookMetadataExceptionTestFile.from_nbmeta_config(
#      64             path, nbmeta_config, test_name
#      65         )
#      67 env = {}
#      68 with open(path) as f:
#
# File /opt/anaconda3/envs/eds232-env/lib/python3.10/site-packages/otter/test_files/metadata_test.py:54, in _NotebookMetadataTestFileMixin.from_nbmeta_config(cls, path, nbmeta_config, test_name)
#      52 test_spec = nbmeta_config.tests
#      53 if test_name not in test_spec:
# ---> 54     raise ValueError(f"Test {test_name} not found")
#      56 test_spec = test_spec[test_name]
#      57 return cls.from_metadata(test_spec, path=path)
#
# ValueError: Test q3 not found

# %% [markdown]
# ## 4.
#
# Display the data type of each column using `df.info()`. Which columns are numeric and which are categorical?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68 entries, 0 to 67
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   author           68 non-null     object
#  1   year_pub         68 non-null     int64
#  2   area_ha          68 non-null     float64
#  3   dna_richness     68 non-null     int64
#  4   trad_richness    68 non-null     int64
#  5   dna_only         68 non-null     int64
#  6   trad_only        68 non-null     int64
#  7   shared           68 non-null     int64
#  8   union            68 non-null     int64
#  9   marker_count     68 non-null     int64
#  10  locus            68 non-null     object
#  11  marker_cat       68 non-null     object
#  12  gear_cat         68 non-null     object
#  13  match_effort     68 non-null     object
#  14  field_reps       68 non-null     int64
#  15  rep_vol_liter    68 non-null     float64
#  16  total_vol_liter  68 non-null     float64
# dtypes: float64(3), int64(9), object(5)
# memory usage: 9.2+ KB

# %% [markdown]
# `author`, `locus`, `marker_cat`, `gear_cat`, and `match_effort` are categorical attributes as their data types are objects. All other columns are numerical attributes as their data types are `int64` or `float64`.

# %% [markdown]
# ## 5.
#
# Compute summary statistics — mean, median, min, max, and std — for `dna_richness` and `trad_richness`. Store the result in a data frame called `stats` with the following row names `mean`, `median`, `min`, `max`, `std` and column names `dna_richness` and `trad_richness`.

# %%
stats = pd.DataFrame({
    'dna_richness': [df['dna_richness'].mean(), df['dna_richness'].median(), df['dna_richness'].std(), df['dna_richness'].min(), df['dna_richness'].max()],
    'trad_richness': [df['trad_richness'].mean(), df['trad_richness'].median(), df['trad_richness'].std(), df['trad_richness'].min(), df['trad_richness'].max()]
}, index = ['mean', 'median', 'std', 'min', 'max'])
stats
# Out:
#         dna_richness  trad_richness
# mean       12.382353      12.073529
# median      9.500000      11.000000
# std        12.996015       9.692767
# min         0.000000       1.000000
# max        92.000000      62.000000

# %%
grader.check("q5")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 grader.check("q5")
#
# File /opt/anaconda3/envs/eds232-env/lib/python3.10/site-packages/otter/check/utils.py:241, in logs_event.<locals>.event_logger(wrapped, self, args, kwargs)
#     239 except Exception as e:
#     240     self._log_event(event_type, success=False, error=e)
# --> 241     raise e
#     243 if ret is None:
#     244     ret = LoggedEventReturnValue(None)
#
# File /opt/anaconda3/envs/eds232-env/lib/python3.10/site-packages/otter/check/utils.py:237, in logs_event.<locals>.event_logger(wrapped, self, args, kwargs)
#     232 """
#     233 Runs a method, catching any errors and logging the call. Returns the unwrapped return value
#     234 of the wrapped function.
#     235 """
#     236 try:
# --> 237     ret: Optional[LoggedEventReturnValue[T]] = wrapped(*args, **kwargs)
#     239 except Exception as e:
#     240     self._log_event(event_type, success=False, error=e)
#
# File /opt/anaconda3/envs/eds232-env/lib/python3.10/site-packages/otter/check/notebook.py:286, in Notebook.check(self, question, global_env)
#     284 # run the check
#     285 self._logger.debug(f"Calling checker")
# --> 286 result = Checker.check(test_path, self._nbmeta_config, test_name, global_env)
#     288 return LoggedEventReturnValue(result, question=question, shelve_env=global_env)
#
# File /opt/anaconda3/envs/eds232-env/lib/python3.10/site-packages/otter/execute/checker.py:80, in Checker.check(cls, nb_or_test_path, nbmeta_config, test_name, global_env)
#      58 @classmethod
#      59 def check(
#      60     cls,
#    (...)
#      64     global_env: Optional[dict[str, Any]] = None,
#      65 ) -> TestFile:
#      66     """
#      67     Checks a global environment against a test, which may be stored in a file or in a notebook's
#      68     metadata.
#    (...)
#      78         given global environment
#      79     """
# ---> 80     test = create_test_file(nb_or_test_path, nbmeta_config, test_name=test_name)
#      82     if global_env is None:
#      83         global_env = inspect.currentframe().f_back.f_globals
#
# File /opt/anaconda3/envs/eds232-env/lib/python3.10/site-packages/otter/test_files/__init__.py:63, in create_test_file(path, nbmeta_config, test_name)
#      60         return NotebookMetadataOKTestFile.from_nbmeta_config(path, nbmeta_config, test_name)
#      62     else:
# ---> 63         return NotebookMetadataExceptionTestFile.from_nbmeta_config(
#      64             path, nbmeta_config, test_name
#      65         )
#      67 env = {}
#      68 with open(path) as f:
#
# File /opt/anaconda3/envs/eds232-env/lib/python3.10/site-packages/otter/test_files/metadata_test.py:54, in _NotebookMetadataTestFileMixin.from_nbmeta_config(cls, path, nbmeta_config, test_name)
#      52 test_spec = nbmeta_config.tests
#      53 if test_name not in test_spec:
# ---> 54     raise ValueError(f"Test {test_name} not found")
#      56 test_spec = test_spec[test_name]
#      57 return cls.from_metadata(test_spec, path=path)
#
# ValueError: Test q5 not found

# %% [markdown]
# ## 6.
#
# How many lakes had eDNA detect **more** species than conventional surveys? How many had conventional surveys detect **more** species? How many were **tied**?
#
# Store your answers in variables called `edna_greater`, `trad_greater`, and `tied`.

# %%
edna_greater = (df['dna_richness'] > df['trad_richness']).sum()
trad_greater = (df['trad_richness'] > df['dna_richness']).sum()
tied         = (df['dna_richness'] == df['trad_richness']).sum()

# %%
grader.check("q6")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 grader.check("q6")
#
# File /opt/anaconda3/envs/eds232-env/lib/python3.10/site-packages/otter/check/utils.py:241, in logs_event.<locals>.event_logger(wrapped, self, args, kwargs)
#     239 except Exception as e:
#     240     self._log_event(event_type, success=False, error=e)
# --> 241     raise e
#     243 if ret is None:
#     244     ret = LoggedEventReturnValue(None)
#
# File /opt/anaconda3/envs/eds232-env/lib/python3.10/site-packages/otter/check/utils.py:237, in logs_event.<locals>.event_logger(wrapped, self, args, kwargs)
#     232 """
#     233 Runs a method, catching any errors and logging the call. Returns the unwrapped return value
#     234 of the wrapped function.
#     235 """
#     236 try:
# --> 237     ret: Optional[LoggedEventReturnValue[T]] = wrapped(*args, **kwargs)
#     239 except Exception as e:
#     240     self._log_event(event_type, success=False, error=e)
#
# File /opt/anaconda3/envs/eds232-env/lib/python3.10/site-packages/otter/check/notebook.py:286, in Notebook.check(self, question, global_env)
#     284 # run the check
#     285 self._logger.debug(f"Calling checker")
# --> 286 result = Checker.check(test_path, self._nbmeta_config, test_name, global_env)
#     288 return LoggedEventReturnValue(result, question=question, shelve_env=global_env)
#
# File /opt/anaconda3/envs/eds232-env/lib/python3.10/site-packages/otter/execute/checker.py:80, in Checker.check(cls, nb_or_test_path, nbmeta_config, test_name, global_env)
#      58 @classmethod
#      59 def check(
#      60     cls,
#    (...)
#      64     global_env: Optional[dict[str, Any]] = None,
#      65 ) -> TestFile:
#      66     """
#      67     Checks a global environment against a test, which may be stored in a file or in a notebook's
#      68     metadata.
#    (...)
#      78         given global environment
#      79     """
# ---> 80     test = create_test_file(nb_or_test_path, nbmeta_config, test_name=test_name)
#      82     if global_env is None:
#      83         global_env = inspect.currentframe().f_back.f_globals
#
# File /opt/anaconda3/envs/eds232-env/lib/python3.10/site-packages/otter/test_files/__init__.py:63, in create_test_file(path, nbmeta_config, test_name)
#      60         return NotebookMetadataOKTestFile.from_nbmeta_config(path, nbmeta_config, test_name)
#      62     else:
# ---> 63         return NotebookMetadataExceptionTestFile.from_nbmeta_config(
#      64             path, nbmeta_config, test_name
#      65         )
#      67 env = {}
#      68 with open(path) as f:
#
# File /opt/anaconda3/envs/eds232-env/lib/python3.10/site-packages/otter/test_files/metadata_test.py:54, in _NotebookMetadataTestFileMixin.from_nbmeta_config(cls, path, nbmeta_config, test_name)
#      52 test_spec = nbmeta_config.tests
#      53 if test_name not in test_spec:
# ---> 54     raise ValueError(f"Test {test_name} not found")
#      56 test_spec = test_spec[test_name]
#      57 return cls.from_metadata(test_spec, path=path)
#
# ValueError: Test q6 not found

# %% [markdown]
# ## 7.
#
# Which lake has the **highest total species richness** (`union`)? Store the row as a `pandas.Series` called `top_lake`, selecting only the `author`, `area_ha`, and `union` columns.

# %%
top_lake = df.loc[df['union'].idxmax(), ['author', 'area_ha', 'union']]
top_lake
# Out:
# author         Doble
# area_ha    3290000.0
# union            103
# Name: 1, dtype: object

# %%
grader.check("q7")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 grader.check("q7")
#
# File /opt/anaconda3/envs/eds232-env/lib/python3.10/site-packages/otter/check/utils.py:241, in logs_event.<locals>.event_logger(wrapped, self, args, kwargs)
#     239 except Exception as e:
#     240     self._log_event(event_type, success=False, error=e)
# --> 241     raise e
#     243 if ret is None:
#     244     ret = LoggedEventReturnValue(None)
#
# File /opt/anaconda3/envs/eds232-env/lib/python3.10/site-packages/otter/check/utils.py:237, in logs_event.<locals>.event_logger(wrapped, self, args, kwargs)
#     232 """
#     233 Runs a method, catching any errors and logging the call. Returns the unwrapped return value
#     234 of the wrapped function.
#     235 """
#     236 try:
# --> 237     ret: Optional[LoggedEventReturnValue[T]] = wrapped(*args, **kwargs)
#     239 except Exception as e:
#     240     self._log_event(event_type, success=False, error=e)
#
# File /opt/anaconda3/envs/eds232-env/lib/python3.10/site-packages/otter/check/notebook.py:286, in Notebook.check(self, question, global_env)
#     284 # run the check
#     285 self._logger.debug(f"Calling checker")
# --> 286 result = Checker.check(test_path, self._nbmeta_config, test_name, global_env)
#     288 return LoggedEventReturnValue(result, question=question, shelve_env=global_env)
#
# File /opt/anaconda3/envs/eds232-env/lib/python3.10/site-packages/otter/execute/checker.py:80, in Checker.check(cls, nb_or_test_path, nbmeta_config, test_name, global_env)
#      58 @classmethod
#      59 def check(
#      60     cls,
#    (...)
#      64     global_env: Optional[dict[str, Any]] = None,
#      65 ) -> TestFile:
#      66     """
#      67     Checks a global environment against a test, which may be stored in a file or in a notebook's
#      68     metadata.
#    (...)
#      78         given global environment
#      79     """
# ---> 80     test = create_test_file(nb_or_test_path, nbmeta_config, test_name=test_name)
#      82     if global_env is None:
#      83         global_env = inspect.currentframe().f_back.f_globals
#
# File /opt/anaconda3/envs/eds232-env/lib/python3.10/site-packages/otter/test_files/__init__.py:63, in create_test_file(path, nbmeta_config, test_name)
#      60         return NotebookMetadataOKTestFile.from_nbmeta_config(path, nbmeta_config, test_name)
#      62     else:
# ---> 63         return NotebookMetadataExceptionTestFile.from_nbmeta_config(
#      64             path, nbmeta_config, test_name
#      65         )
#      67 env = {}
#      68 with open(path) as f:
#
# File /opt/anaconda3/envs/eds232-env/lib/python3.10/site-packages/otter/test_files/metadata_test.py:54, in _NotebookMetadataTestFileMixin.from_nbmeta_config(cls, path, nbmeta_config, test_name)
#      52 test_spec = nbmeta_config.tests
#      53 if test_name not in test_spec:
# ---> 54     raise ValueError(f"Test {test_name} not found")
#      56 test_spec = test_spec[test_name]
#      57 return cls.from_metadata(test_spec, path=path)
#
# ValueError: Test q7 not found

# %% [markdown]
# ## 8.
#
# Create a new column in `df` called `dna_advantage` defined as:
#
# ```
# dna_advantage = dna_richness - trad_richness
# ```
#
# A positive value means eDNA found more species; a negative value means conventional surveys found more. Display the first 5 rows of `author`, `dna_richness`, `trad_richness`, and `dna_advantage`.

# %%
df['dna_advantage'] = df['dna_richness'] - df['trad_richness']
df.loc[:, ['author', 'dna_richness', 'trad_richness', 'dna_advantage']].head(5)
# Out:
#    author  dna_richness  trad_richness  dna_advantage
# 0  Civade            14             18             -4
# 1   Doble            92             62             30
# 2   Evans            15             10              5
# 3   Fujii             0              7             -7
# 4   Fujii             2              8             -6

# %%
grader.check("q8")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 grader.check("q8")
#
# File /opt/anaconda3/envs/eds232-env/lib/python3.10/site-packages/otter/check/utils.py:241, in logs_event.<locals>.event_logger(wrapped, self, args, kwargs)
#     239 except Exception as e:
#     240     self._log_event(event_type, success=False, error=e)
# --> 241     raise e
#     243 if ret is None:
#     244     ret = LoggedEventReturnValue(None)
#
# File /opt/anaconda3/envs/eds232-env/lib/python3.10/site-packages/otter/check/utils.py:237, in logs_event.<locals>.event_logger(wrapped, self, args, kwargs)
#     232 """
#     233 Runs a method, catching any errors and logging the call. Returns the unwrapped return value
#     234 of the wrapped function.
#     235 """
#     236 try:
# --> 237     ret: Optional[LoggedEventReturnValue[T]] = wrapped(*args, **kwargs)
#     239 except Exception as e:
#     240     self._log_event(event_type, success=False, error=e)
#
# File /opt/anaconda3/envs/eds232-env/lib/python3.10/site-packages/otter/check/notebook.py:286, in Notebook.check(self, question, global_env)
#     284 # run the check
#     285 self._logger.debug(f"Calling checker")
# --> 286 result = Checker.check(test_path, self._nbmeta_config, test_name, global_env)
#     288 return LoggedEventReturnValue(result, question=question, shelve_env=global_env)
#
# File /opt/anaconda3/envs/eds232-env/lib/python3.10/site-packages/otter/execute/checker.py:80, in Checker.check(cls, nb_or_test_path, nbmeta_config, test_name, global_env)
#      58 @classmethod
#      59 def check(
#      60     cls,
#    (...)
#      64     global_env: Optional[dict[str, Any]] = None,
#      65 ) -> TestFile:
#      66     """
#      67     Checks a global environment against a test, which may be stored in a file or in a notebook's
#      68     metadata.
#    (...)
#      78         given global environment
#      79     """
# ---> 80     test = create_test_file(nb_or_test_path, nbmeta_config, test_name=test_name)
#      82     if global_env is None:
#      83         global_env = inspect.currentframe().f_back.f_globals
#
# File /opt/anaconda3/envs/eds232-env/lib/python3.10/site-packages/otter/test_files/__init__.py:63, in create_test_file(path, nbmeta_config, test_name)
#      60         return NotebookMetadataOKTestFile.from_nbmeta_config(path, nbmeta_config, test_name)
#      62     else:
# ---> 63         return NotebookMetadataExceptionTestFile.from_nbmeta_config(
#      64             path, nbmeta_config, test_name
#      65         )
#      67 env = {}
#      68 with open(path) as f:
#
# File /opt/anaconda3/envs/eds232-env/lib/python3.10/site-packages/otter/test_files/metadata_test.py:54, in _NotebookMetadataTestFileMixin.from_nbmeta_config(cls, path, nbmeta_config, test_name)
#      52 test_spec = nbmeta_config.tests
#      53 if test_name not in test_spec:
# ---> 54     raise ValueError(f"Test {test_name} not found")
#      56 test_spec = test_spec[test_name]
#      57 return cls.from_metadata(test_spec, path=path)
#
# ValueError: Test q8 not found

# %% [markdown]
# ## 9.
#
# Filter the dataframe to only lakes where **both** conditions are true:
# - `area_ha` is greater than 1000 hectares
# - `total_vol_liter` is greater than the median `total_vol_liter`
#
# Store the filtered dataframe in a variable called `large_lakes`. Then store the count of matching lakes in `n_large` and their mean `union` richness in `mean_union_large`.

# %%
# Your answer here.
large_lakes = df[(df['area_ha'] > 1000) & (df['total_vol_liter'] > df['total_vol_liter'].median())]
n_large = large_lakes.shape[0]
mean_union_large = large_lakes['union'].mean()

# %%
grader.check("q9")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 grader.check("q9")
#
# File /opt/anaconda3/envs/eds232-env/lib/python3.10/site-packages/otter/check/utils.py:241, in logs_event.<locals>.event_logger(wrapped, self, args, kwargs)
#     239 except Exception as e:
#     240     self._log_event(event_type, success=False, error=e)
# --> 241     raise e
#     243 if ret is None:
#     244     ret = LoggedEventReturnValue(None)
#
# File /opt/anaconda3/envs/eds232-env/lib/python3.10/site-packages/otter/check/utils.py:237, in logs_event.<locals>.event_logger(wrapped, self, args, kwargs)
#     232 """
#     233 Runs a method, catching any errors and logging the call. Returns the unwrapped return value
#     234 of the wrapped function.
#     235 """
#     236 try:
# --> 237     ret: Optional[LoggedEventReturnValue[T]] = wrapped(*args, **kwargs)
#     239 except Exception as e:
#     240     self._log_event(event_type, success=False, error=e)
#
# File /opt/anaconda3/envs/eds232-env/lib/python3.10/site-packages/otter/check/notebook.py:286, in Notebook.check(self, question, global_env)
#     284 # run the check
#     285 self._logger.debug(f"Calling checker")
# --> 286 result = Checker.check(test_path, self._nbmeta_config, test_name, global_env)
#     288 return LoggedEventReturnValue(result, question=question, shelve_env=global_env)
#
# File /opt/anaconda3/envs/eds232-env/lib/python3.10/site-packages/otter/execute/checker.py:80, in Checker.check(cls, nb_or_test_path, nbmeta_config, test_name, global_env)
#      58 @classmethod
#      59 def check(
#      60     cls,
#    (...)
#      64     global_env: Optional[dict[str, Any]] = None,
#      65 ) -> TestFile:
#      66     """
#      67     Checks a global environment against a test, which may be stored in a file or in a notebook's
#      68     metadata.
#    (...)
#      78         given global environment
#      79     """
# ---> 80     test = create_test_file(nb_or_test_path, nbmeta_config, test_name=test_name)
#      82     if global_env is None:
#      83         global_env = inspect.currentframe().f_back.f_globals
#
# File /opt/anaconda3/envs/eds232-env/lib/python3.10/site-packages/otter/test_files/__init__.py:63, in create_test_file(path, nbmeta_config, test_name)
#      60         return NotebookMetadataOKTestFile.from_nbmeta_config(path, nbmeta_config, test_name)
#      62     else:
# ---> 63         return NotebookMetadataExceptionTestFile.from_nbmeta_config(
#      64             path, nbmeta_config, test_name
#      65         )
#      67 env = {}
#      68 with open(path) as f:
#
# File /opt/anaconda3/envs/eds232-env/lib/python3.10/site-packages/otter/test_files/metadata_test.py:54, in _NotebookMetadataTestFileMixin.from_nbmeta_config(cls, path, nbmeta_config, test_name)
#      52 test_spec = nbmeta_config.tests
#      53 if test_name not in test_spec:
# ---> 54     raise ValueError(f"Test {test_name} not found")
#      56 test_spec = test_spec[test_name]
#      57 return cls.from_metadata(test_spec, path=path)
#
# ValueError: Test q9 not found

# %% [markdown]
# ## 10.
#
# Group lakes by `gear_cat` (single vs. multiple conventional survey methods) **and** `marker_cat` (single vs. multiple eDNA markers). Using `gear_cat` as rows and `marker_cat` as columns, compute a pivot table showing the mean `union` (total species richness) and mean `dna_advantage` for each combination. Round values to 2 decimal places and exclude the `unspecified` category from your interpretation.
#
# Store the result in a variable called `pivot`.
#
# **Hint — `pivot_table` syntax:**
# ```python
# df.pivot_table(
#     values=[...],      # columns to aggregate
#     index=...,         # variable to use as rows
#     columns=...,       # variable to use as columns
#     aggfunc="mean"     # aggregation function
# ).round(2)
# ```

# %%
pivot = df.pivot_table(
    values=['union', 'dna_advantage'],
    index='gear_cat',
    columns='marker_cat',
    aggfunc='mean'
).round(2)
pivot
# Out:
#             dna_advantage           union
# marker_cat       multiple single multiple single
# gear_cat
# multiple             2.67  -2.36    14.33  16.03
# single              30.00  -0.60   103.00   8.00
# unspecified           NaN   0.00      NaN   1.00

# %%
grader.check("q10")

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# Which combination of `gear_cat` and `marker_cat` detects the most species overall (highest mean `union`)? Answer in the markdown cell below

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->

# %% [markdown]
# ---
#
# **Run the cell below to receive credit for all auto graded questions.**

# %%
grader.check_all()
